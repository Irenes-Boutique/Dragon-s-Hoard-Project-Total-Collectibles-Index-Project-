# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\varia\OneDrive\Dragon Hoard's Index\Datasets\RESERVED_LIST.csv")

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
df.head()
# Out:
#                Price
# Date
# 2010-09-16  10335.17
# 2010-09-19  10336.45
# 2010-09-20  10337.80
# 2010-09-21  10341.25
# 2010-09-22  10343.93

# %%
df_monthly = df.resample('MS').first()
df_monthly.head()
# Out:
#                Price
# Date
# 2010-09-01  10335.17
# 2010-10-01  10426.77
# 2010-11-01  10508.76
# 2010-12-01  10537.60
# 2011-01-01  10297.46

# %%
df_monthly.shape
# Out:
# (187, 1)

# %%
plt.plot(df_monthly)
plt.show()

# %%
df_monthly.to_csv("MtG Reserved List Monthly.csv")
